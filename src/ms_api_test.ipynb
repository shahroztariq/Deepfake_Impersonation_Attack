# %% [markdown]
# # Check Conda Env Name

# %%
import sys
sys.executable.split('/')[-3]
# Out:
# 'pytor'

# %% [markdown]
# # Imports

# %%
import cv2
import os
import matplotlib.pyplot as plt
import glob
import time
import gc
import pandas as pd
import numpy as np
import boto3
from PIL import Image
import io
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import ImageDraw, ImageFont
from glob import glob
from pprint import pprint
import pprint
from difflib import SequenceMatcher

# %% [markdown]
# # Initialization

# %%
BUCKET = "amazon-rekognition"
KEY = "search.jpg"
COLLECTION = "my-collection-id"

ACCESS_ID = 'AKIAIU5XIM7L2SDVB2VA'
ACCESS_KEY = 'Q1Skb4QGYqUnXDpOttvVLLDQcjV+gvhXtv1uQ5Dk'

client=boto3.client('rekognition', region_name='ap-northeast-2', aws_access_key_id=ACCESS_ID, aws_secret_access_key=ACCESS_KEY)
# rekognition = boto3.client('rekognition')

# img_subtraction_folder = '/media/data2/dataset/DF/Fake_Localized'

# if not os.path.exists(img_subtraction_folder):
#     os.mkdir(img_subtraction_folder)

# %% [markdown]
# # Methods

# %%
def recognize_celebrities(photo):

    with open(photo, 'rb') as image:
        response = client.recognize_celebrities(Image={'Bytes': image.read()})

    print('Detected faces for ' + photo)
    image = Image.open(photo)
    imgWidth,imgHeight  = image.size
    draw = ImageDraw.Draw(image)
#     font = ImageFont.truetype(font=None, size=12, index=0, encoding='')
    for celebrity in response['CelebrityFaces']:
#         print ('Name: ' + celebrity['Name'])
#         print ('Confidence:',celebrity['MatchConfidence'])#celebrity.keys())
#         print ('Id: ' + celebrity['Id'])
#         print ('Position:')
#         print ('   Left: ' + '{:.2f}'.format(celebrity['Face']['BoundingBox']['Height']))
#         print ('   Top: ' + '{:.2f}'.format(celebrity['Face']['BoundingBox']['Top']))
#         print ('Info')
#         for url in celebrity['Urls']:
#             print ('   ' + url)
#         print()
        
        
        box = celebrity['Face']['BoundingBox']
        left = imgWidth * box['Left']
        top = imgHeight * box['Top']
        width = imgWidth * box['Width']
        height = imgHeight * box['Height']
        points = (
                    (left,top),
                    (left + width, top),
                    (left + width, top + height),
                    (left , top + height),
                    (left, top)
        )
        draw.line(points, fill='#00d400', width=2)
        fnt = ImageFont.truetype("/usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf",15)

        draw.text((left+(width/10),top), str(celebrity['MatchConfidence'])+":"+celebrity['Name'],fill='#FFFFFF', align ="left",font=fnt)
#     display(image)
#     print(response)
    for celebrity in response['UnrecognizedFaces']:    
        box = celebrity['BoundingBox']
        left = imgWidth * box['Left']
        top = imgHeight * box['Top']
        width = imgWidth * box['Width']
        height = imgHeight * box['Height']
        points = (
                    (left,top),
                    (left + width, top),
                    (left + width, top + height),
                    (left , top + height),
                    (left, top)
        )
        draw.line(points, fill='#d40000', width=2)
#     display(image)
    return len(response['CelebrityFaces']),response,image
def get_celebrity_dic(path):
    dic=dict()
    with open(path,"r") as csv_file:
        for line in csv_file:
            cols=line.split(",")
            dic[cols[0]]=cols[1].rstrip()
    
    # for key, value in dic.items():
    #         print(key,value)
    return dic
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
def check_case(a,b,c):
    if similar(a,c)>0.90:
        return "case 1" #result is source
    elif similar(b,c)>0.90:
        return "case 2" #result is target
    else:
        return "case 3" #result is someone-else
    
def check_case_dfP(a,b):
    if similar(a,c)>0.95:
        return "case 1" #result is source
    else:
        return "case 2" #result is someone-else
def make_output_line(first,second,src_celeb_name,tar_celeb_name):
    if first!="" and second !="":
        first_str=str(first['Name']+","+str(first['MatchConfidence']))
        second_str=str(second['Name']+","+str(second['MatchConfidence']))
        case=check_case(first['Name'],second['Name'],tar_celeb_name)
        line="{},{},{},{},{},{},{}".format(str(src_celeb_name),
                                           str(tar_celeb_name),
                                           first['Name'],
                                           str(first['MatchConfidence']),
                                           second['Name'],
                                           str(second['MatchConfidence']),
                                           case)
        return line
    elif first!="" and second =="":
        case="case 4"#result is no-one
        line="{},{},{},{},{},{},{}".format(str(src_celeb_name),
                                           str(tar_celeb_name),
                                           first['Name'],
                                           str(first['MatchConfidence']),
                                           "",
                                           "",
                                           case)
        return line
    elif first=="" and second !="":
        case=check_case("",second['Name'],tar_celeb_name)+"_1"
        line="{},{},{},{},{},{},{}".format(str(src_celeb_name),
                                           str(tar_celeb_name),
                                           "",
                                           "",
                                           second['Name'],
                                           str(second['MatchConfidence']),
                                           case)
        return line
    else:
        case="case 5"# failed to find src and target
        line="{},{},{},{},{},{},{}".format(str(src_celeb_name),
                                           str(tar_celeb_name),
                                           "",
                                           "",
                                           "",
                                           "",
                                           case)
    return line

# %% [markdown]
# # Vox2

# %%
dirs=glob("first-order-model/first-order-motion-model/vox2_ft_32_plots/*")
celeb_dic=get_celebrity_dic("vox_id_utf-8.csv") 
# pprint(dirs)
with open("first-order-model/first-order-motion-model/vox2_ft_32_plots_result/results.csv","w",buffering=1) as csv_file:
    csv_file.write("Filename,Real, Fake, Real Prediction, Real Prediction Confidence, Fake Prediction,Fake Prediction Confidence,Case\n") 
    for dir in dirs:
    #     print(dir)
        actor_name=os.path.basename(dir)
        print(actor_name)
        files=(glob(os.path.join(dir,"*")))
        for file in files:   
    #         pprint(files)
            file_name=os.path.basename(file)
    #         print(file_name)
            celeb_count,response,image=recognize_celebrities(file)
            print("Celebrities detected: " + str(celeb_count))
            output_s = pprint.pformat(response)
            output_dir=os.path.join("first-order-model/first-order-motion-model/","vox2_ft_32_plots_result",actor_name)
            output_filename=os.path.join(output_dir,file_name)
            output_log_filename=os.path.join(output_dir,"log_"+os.path.splitext(file_name)[0]+".txt")
    #         print(output_dir)
    #         print(output_filename)
    #         print(output_log_filename)
            if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
            open(output_log_filename, 'w').write(output_s)
            image.save(output_filename)
            real_top=99999
            real_left=99999
            real=99999
            imgWidth,imgHeight  = image.size
            lines=[]
            first=""
            second=""
            third=""
            fourth=""
#             others=[]
            for celebrity in response['CelebrityFaces']:
                box = celebrity['Face']['BoundingBox']
                left = imgWidth * box['Left']
                top = imgHeight * box['Top']
                width = imgWidth * box['Width']
                height = imgHeight * box['Height']
                bot = top + height
                right = left + width
                center_h=top + (height/2)
                center_w=left + (width/2)
#                 if top<(imgHeight/2) and left<(imgWidth/2):#first quadrant
#                     first=celebrity#str(celebrity['Name']+","+str(celebrity['MatchConfidence']))
#                 else:
#                     others.append(celebrity)
                    
                if center_h<(imgHeight/2) and center_w<(imgWidth/2):#first quadrant
                    first=celebrity
                if center_h<(imgHeight/2) and center_w>(imgWidth/2):#second quadrant
                    second=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w<(imgWidth/2):#third quadrant
                    third=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w>(imgWidth/2):#fourth quadrant
                    fourth=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))   


            ids=file_name.split(".")[0].split("_")[1:]
            real_id=ids[0]
            fake_ids=ids[1:]

    #         print(celeb_dic[real_id],celeb_dic[fake_ids[0]])
#             for ii,other in enumerate(fake_ids):
                
#                 csv_file.write(str(file+","+make_output_line(first,other,celeb_dic[real_id],celeb_dic[fake_ids[ii]])+"\n"))
                
            if len(fake_ids)>0:
                csv_file.write(str(file+","+make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]])+"\n"))
            if len(fake_ids) > 1:
                csv_file.write(str(file+","+make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]])+"\n"))
            if len(fake_ids) > 2:
                csv_file.write(str(file+","+make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]])+"\n"))
#             print(make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]]))
#             print(make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]]))
#             print(make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]]))

#             print()
            print("-_-_-_-_-_-_-_-")
    #         break
#         break
# Out:
# David Spade
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/143_n002056_n002056_n002056_n002056.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/149_n002056_n002056_n002056_n002056.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/142_n002056_n002056_n002056_n002056.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/145_n002056_n002056_n002056_n002056.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/140_n002056_n002056_n002056_n002056.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/144_n002056_n002056_n002056_n002056.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/141_n002056_n002056_n002056_n002056.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/148_n002056_n002056_n002056_n002056.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/147_n002056_n002056_n002056_n002056.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/David Spade/146_n002056_n002056_n002056_n002056.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Fawad Afzal Khan
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/201_n002744_n002744_n002744_n002744.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/205_n002744_n002744_n002744_n002744.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/209_n002744_n002744_n002744_n002744.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/202_n002744_n002744_n002744_n002744.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/204_n002744_n002744_n002744_n002744.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/206_n002744_n002744_n002744_n002744.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/203_n002744_n002744_n002744_n002744.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/207_n002744_n002744_n002744_n002744.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/208_n002744_n002744_n002744_n002744.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fawad Afzal Khan/200_n002744_n002744_n002744_n002744.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Jordan Henderson
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/295_n004294_n004294_n004294_n004294.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/290_n004294_n004294_n004294_n004294.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/296_n004294_n004294_n004294_n004294.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/291_n004294_n004294_n004294_n004294.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/294_n004294_n004294_n004294_n004294.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/299_n004294_n004294_n004294_n004294.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/297_n004294_n004294_n004294_n004294.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/298_n004294_n004294_n004294_n004294.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/292_n004294_n004294_n004294_n004294.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Jordan Henderson/293_n004294_n004294_n004294_n004294.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Emmy Rossum
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/186_n002547_n002547_n002547_n002547.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/189_n002547_n002547_n002547_n002547.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/184_n002547_n002547_n002547_n002547.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/180_n002547_n002547_n002547_n002547.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/182_n002547_n002547_n002547_n002547.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/187_n002547_n002547_n002547_n002547.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/188_n002547_n002547_n002547_n002547.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/181_n002547_n002547_n002547_n002547.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/183_n002547_n002547_n002547_n002547.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Emmy Rossum/185_n002547_n002547_n002547_n002547.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Katie Perry
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Perry/320_n004655_n004655_n004655_n004655.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Perry/321_n004655_n004655_n004655_n004655.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Perry/329_n004655_n004655_n004655_n004655.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Perry/325_n004655_n004655_n004655_n004655.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Perry/328_n004655_n004655_n004655_n004655.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Perry
png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Karen Gillan/317_n004569_n004569_n004569_n004569.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Karen Gillan/313_n004569_n004569_n004569_n004569.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Karen Gillan/316_n004569_n004569_n004569_n004569.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Karen Gillan/311_n004569_n004569_n004569_n004569.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Katie Price
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/337_n004656_n004656_n004656_n004656.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/335_n004656_n004656_n004656_n004656.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/338_n004656_n004656_n004656_n004656.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/336_n004656_n004656_n004656_n004656.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/333_n004656_n004656_n004656_n004656.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/332_n004656_n004656_n004656_n004656.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/331_n004656_n004656_n004656_n004656.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/339_n004656_n004656_n004656_n004656.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/330_n004656_n004656_n004656_n004656.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Katie Price/334_n004656_n004656_n004656_n004656.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Fan Bingbing
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/193_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/198_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/194_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/195_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/196_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/190_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/191_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/192_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/197_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Fan Bingbing/199_n002724_n002724_n002724_n002724.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Britney Spears
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/97_n001228_n001228_n001228_n001228.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/98_n001228_n001228_n001228_n001228.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/94_n001228_n001228_n001228_n001228.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/93_n001228_n001228_n001228_n001228.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/90_n001228_n001228_n001228_n001228.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/95_n001228_n001228_n001228_n001228.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/96_n001228_n001228_n001228_n001228.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/99_n001228_n001228_n001228_n001228.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/92_n001228_n001228_n001228_n001228.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Britney Spears/91_n001228_n001228_n001228_n001228.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Ashley Tisdale
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/57_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/50_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/59_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/58_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/52_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/56_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/53_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/51_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/54_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Ashley Tisdale/55_n000812_n000812_n000812_n000812.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# LeBron James
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/360_n005054_n005054_n005054_n005054.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/367_n005054_n005054_n005054_n005054.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/364_n005054_n005054_n005054_n005054.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/369_n005054_n005054_n005054_n005054.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/368_n005054_n005054_n005054_n005054.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/363_n005054_n005054_n005054_n005054.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/361_n005054_n005054_n005054_n005054.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/365_n005054_n005054_n005054_n005054.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/366_n005054_n005054_n005054_n005054.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/LeBron James/362_n005054_n005054_n005054_n005054.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Sebastián Piñera
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/459_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/457_n007873_n007873_n007873_n007873.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/458_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/453_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/451_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/450_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/454_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/456_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/452_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox2_ft_32_plots/Sebastián Piñera/455_n007873_n007873_n007873_n007873.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-

# %% [markdown]
# # Vox 1

# %%
dirs=glob("first-order-model/first-order-motion-model/vox1_32_plots/*")
celeb_dic=get_celebrity_dic("vox1_id.csv") 
# pprint(dirs)
with open("first-order-model/first-order-motion-model/vox1_32_plots_result/results.csv","w",buffering=1) as csv_file:
    csv_file.write("Filename,Real, Fake, Real Prediction, Real Prediction Confidence, Fake Prediction,Fake Prediction Confidence,Case\n") 
    for dir in dirs:
    #     print(dir)
        actor_name=os.path.basename(dir)
        print(actor_name)
        files=(glob(os.path.join(dir,"*")))
        for file in files:   
    #         pprint(files)
            file_name=os.path.basename(file)
    #         print(file_name)
            celeb_count,response,image=recognize_celebrities(file)
            print("Celebrities detected: " + str(celeb_count))
            output_s = pprint.pformat(response)
            output_dir=os.path.join("first-order-model/first-order-motion-model/","vox1_32_plots_result",actor_name)
            output_filename=os.path.join(output_dir,file_name)
            output_log_filename=os.path.join(output_dir,"log_"+os.path.splitext(file_name)[0]+".txt")
    #         print(output_dir)
    #         print(output_filename)
    #         print(output_log_filename)
            if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
            open(output_log_filename, 'w').write(output_s)
            image.save(output_filename)
            real_top=99999
            real_left=99999
            real=99999
            imgWidth,imgHeight  = image.size
            lines=[]
            first=""
            second=""
            third=""
            fourth=""
#             others=[]
            for celebrity in response['CelebrityFaces']:
                box = celebrity['Face']['BoundingBox']
                left = imgWidth * box['Left']
                top = imgHeight * box['Top']
                width = imgWidth * box['Width']
                height = imgHeight * box['Height']
                bot = top + height
                right = left + width
                center_h=top + (height/2)
                center_w=left + (width/2)
#                 if top<(imgHeight/2) and left<(imgWidth/2):#first quadrant
#                     first=celebrity#str(celebrity['Name']+","+str(celebrity['MatchConfidence']))
#                 else:
#                     others.append(celebrity)
                    
                if center_h<(imgHeight/2) and center_w<(imgWidth/2):#first quadrant
                    first=celebrity
                if center_h<(imgHeight/2) and center_w>(imgWidth/2):#second quadrant
                    second=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w<(imgWidth/2):#third quadrant
                    third=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w>(imgWidth/2):#fourth quadrant
                    fourth=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))   


            ids=file_name.split(".")[0].split("_")[1:]
            real_id=ids[0]
            fake_ids=ids[1:]

    #         print(celeb_dic[real_id],celeb_dic[fake_ids[0]])
#             for ii,other in enumerate(fake_ids):
                
#                 csv_file.write(str(file+","+make_output_line(first,other,celeb_dic[real_id],celeb_dic[fake_ids[ii]])+"\n"))
                
            if len(fake_ids)>0:
                csv_file.write(str(file+","+make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]])+"\n"))
            if len(fake_ids) > 1:
                csv_file.write(str(file+","+make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]])+"\n"))
            if len(fake_ids) > 2:
                csv_file.write(str(file+","+make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]])+"\n"))
#             print(make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]]))
#             print(make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]]))
#             print(make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]]))

#             print()
            print("-_-_-_-_-_-_-_-")
    #         break
#         break
# Out:
# Paul Scheer
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/405_41_41_41_41.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/403_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/408_41_41_41_41.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/409_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/402_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/407_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/404_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/401_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/400_41_41_41_41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Paul Scheer/406_41_41_41_41.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Nicole Richie
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/363_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/360_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/364_37_37_37_37.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/369_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/366_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/365_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/367_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/368_37_37_37_37.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/362_37_37_37_37.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Nicole Richie/361_37_37_37_37.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Mandy Patinkin
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/287_29_29_29_29.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/286_29_29_29_29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/284_29_29_29_29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/288_29_29_29_29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/281_29_29_29_29.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/283_29_29_29_29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/289_29_29_29_29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/285_29_29_29_29.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/280_29_29_29_29.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Mandy Patinkin/282_29_29_29_29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Abigail Spencer
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/15_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/18_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/10_2_2_2_2.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/13_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/12_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/14_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/16_2_2_2_2.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/19_2_2_2_2.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/17_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Abigail Spencer/11_2_2_2_2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Max Thieriot
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/301_31_31_31_31.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/309_31_31_31_31.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/304_31_31_31_31.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/303_31_31_31_31.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/308_31_31_31_31.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/302_31_31_31_31.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/305_31_31_31_31.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/306_31_31_31_31.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/307_31_31_31_31.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Max Thieriot/300_31_31_31_31.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Chris Hemsworth
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/50_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/55_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/53_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/57_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/51_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/58_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/54_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/59_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/52_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Chris Hemsworth/56_6_6_6_6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Alain Delon
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/28_3_3_3_3.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/24_3_3_3_3.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/29_3_3_3_3.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/23_3_3_3_3.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/25_3_3_3_3.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/22_3_3_3_3.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/20_3_3_3_3.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/26_3_3_3_3.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Alain Delon/21_3_3_3_3.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/
.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Todd Lasance
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/484_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/489_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/486_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/483_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/481_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/488_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/487_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/482_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/480_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Todd Lasance/485_49_49_49_49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Oscar Isaac
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/399_40_40_40_40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/395_40_40_40_40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/393_40_40_40_40.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/391_40_40_40_40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/390_40_40_40_40.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/396_40_40_40_40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/397_40_40_40_40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/392_40_40_40_40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/398_40_40_40_40.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Oscar Isaac/394_40_40_40_40.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Brenda Blethyn
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/48_5_5_5_5.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/40_5_5_5_5.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/42_5_5_5_5.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/45_5_5_5_5.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/49_5_5_5_5.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/46_5_5_5_5.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/43_5_5_5_5.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/44_5_5_5_5.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/41_5_5_5_5.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Brenda Blethyn/47_5_5_5_5.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Kenny Rogers
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/233_24_24_24_24.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/235_24_24_24_24.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/239_24_24_24_24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/238_24_24_24_24.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/232_24_24_24_24.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/231_24_24_24_24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/234_24_24_24_24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/236_24_24_24_24.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/237_24_24_24_24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Kenny Rogers/230_24_24_24_24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Thomas Jane
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/479_48_48_48_48.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/474_48_48_48_48.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/471_48_48_48_48.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/478_48_48_48_48.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/473_48_48_48_48.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/477_48_48_48_48.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/470_48_48_48_48.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/476_48_48_48_48.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/475_48_48_48_48.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/vox1_32_plots/Thomas Jane/472_48_48_48_48.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-

# %% [markdown]
# # FOM

# %%
dirs=glob("first-order-model/first-order-motion-model/FOM_deepfake_plots/*")
celeb_dic=get_celebrity_dic("celebrity_id.csv") 
# pprint(dirs)
with open("first-order-model/first-order-motion-model/FOM_deepfake_plots_result/results.csv","w",buffering=1) as csv_file:
    csv_file.write("Filename,Real, Fake, Real Prediction, Real Prediction Confidence, Fake Prediction,Fake Prediction Confidence,Case\n") 
    for dir in dirs:
    #     print(dir)
        actor_name=os.path.basename(dir)
        print(actor_name)
        files=(glob(os.path.join(dir,"*")))
        for file in files:   
    #         pprint(files)
            file_name=os.path.basename(file)
    #         print(file_name)
            celeb_count,response,image=recognize_celebrities(file)
            print("Celebrities detected: " + str(celeb_count))
            output_s = pprint.pformat(response)
            output_dir=os.path.join("first-order-model/first-order-motion-model/","FOM_deepfake_plots_result",actor_name)
            output_filename=os.path.join(output_dir,file_name)
            output_log_filename=os.path.join(output_dir,"log_"+os.path.splitext(file_name)[0]+".txt")
    #         print(output_dir)
    #         print(output_filename)
    #         print(output_log_filename)
            if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
            open(output_log_filename, 'w').write(output_s)
            image.save(output_filename)
            real_top=99999
            real_left=99999
            real=99999
            imgWidth,imgHeight  = image.size
            lines=[]
            first=""
            second=""
            third=""
            fourth=""
#             others=[]
            for celebrity in response['CelebrityFaces']:
                box = celebrity['Face']['BoundingBox']
                left = imgWidth * box['Left']
                top = imgHeight * box['Top']
                width = imgWidth * box['Width']
                height = imgHeight * box['Height']
                bot = top + height
                right = left + width
                center_h=top + (height/2)
                center_w=left + (width/2)
#                 if top<(imgHeight/2) and left<(imgWidth/2):#first quadrant
#                     first=celebrity#str(celebrity['Name']+","+str(celebrity['MatchConfidence']))
#                 else:
#                     others.append(celebrity)
                    
                if center_h<(imgHeight/2) and center_w<(imgWidth/2):#first quadrant
                    first=celebrity
                if center_h<(imgHeight/2) and center_w>(imgWidth/2):#second quadrant
                    second=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w<(imgWidth/2):#third quadrant
                    third=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w>(imgWidth/2):#fourth quadrant
                    fourth=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))   


            ids=file_name.split(".")[0].split("_")[1:]
            real_id=ids[0]
            fake_ids=ids[1:]

    #         print(celeb_dic[real_id],celeb_dic[fake_ids[0]])
#             for ii,other in enumerate(fake_ids):
                
#                 csv_file.write(str(file+","+make_output_line(first,other,celeb_dic[real_id],celeb_dic[fake_ids[ii]])+"\n"))
                
            if len(fake_ids)>0:
                csv_file.write(str(file+","+make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]])+"\n"))
            if len(fake_ids) > 1:
                csv_file.write(str(file+","+make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]])+"\n"))
            if len(fake_ids) > 2:
                csv_file.write(str(file+","+make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]])+"\n"))
#             print(make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]]))
#             print(make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]]))
#             print(make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]]))

#             print()
            print("-_-_-_-_-_-_-_-")
    #         break
#         break
# Out:
# Emma Watson
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0009_id11_id37_id43_id10.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0004_id11_id8_id0_id1.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0002_id11_id20_id21_id30.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0001_id11_id9_id50_id53.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0007_id11_id58_id22_id17.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0010_id11_id43_id0_id56.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0008_id11_id55_id9_id6.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0000_id11_id59_id29_id2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0006_id11_id38_id2_id51.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0003_id11_id7_id9_id49.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Watson/0005_id11_id28_id54_id26.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Megan Fox
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0000_id46_id13_id53_id32.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0008_id46_id17_id23_id27.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0009_id46_id3_id26_id4.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0004_id46_id22_id27_id8.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0006_id46_id40_id59_id49.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0007_id46_id5_id58_id48.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0002_id46_id20_id42_id57.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0001_id46_id9_id16_id25.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0005_id46_id51_id41_id21.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Megan Fox/0003_id46_id23_id10_id41.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Russell Crowe
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0002_id32_id29_id60_id24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0003_id32_id41_id3_id40.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0005_id32_id11_id41_id6.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0001_id32_id10_id12_id1.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0004_id32_id17_id55_id60.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0007_id32_id24_id39_id2.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0008_id32_id2_id5_id54.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0006_id32_id8_id23_id5.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0000_id32_id19_id48_id8.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Russell Crowe/0009_id32_id37_id57_id59.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Randall Park
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0004_id9_id47_id25_id10.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0007_id9_id39_id41_id0.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0003_id9_id32_id26_id25.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0005_id9_id2_id1_id39.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0000_id9_id33_id44_id49.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0006_id9_id47_id41_id3.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0009_id9_id2_id24_id49.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0002_id9_id0_id27_id56.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0001_id9_id22_id19_id16.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Randall Park/0008_id9_id30_id58_id55.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Emma Stone
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0001_id48_id43_id60_id37.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0006_id48_id53_id45_id50.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0009_id48_id38_id50_id20.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0002_id48_id45_id53_id59.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0007_id48_id56_id53_id58.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0008_id48_id5_id52_id24.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0004_id48_id17_id21_id12.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0003_id48_id17_id10_id7.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0005_id48_id29_id34_id23.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Emma Stone/0000_id48_id25_id28_id21.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Joseph Gordon-Levitt
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0008_id26_id25_id39_id54.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0005_id26_id52_id25_id7.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0009_id26_id3_id44_id60.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0002_id26_id20_id40_id48.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0003_id26_id47_id32_id40.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0000_id26_id3_id61_id37.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0007_id26_id43_id10_id31.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Joseph Gordon-Levitt/0004_id26_id41_id7_id37.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Famke Janssen
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0008_id58_id2_id54_id23.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0000_id58_id42_id2_id17.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0009_id58_id13_id53_id8.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0006_id58_id20_id47_id22.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0001_id58_id39_id22_id43.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0004_id58_id35_id25_id49.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/0003_id58_id32_id42_id13.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Famke Janssen/
png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0005_id4_id16_id56_id11.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0007_id4_id47_id12_id58.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0002_id4_id38_id1_id9.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0000_id4_id33_id5_id23.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0001_id4_id44_id47_id28.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0008_id4_id42_id31_id12.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0009_id4_id30_id26_id13.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Chris Evans/0004_id4_id27_id21_id49.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Jessica Alba
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0001_id43_id29_id27_id51.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0000_id43_id52_id57_id44.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0002_id43_id58_id19_id32.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0008_id43_id7_id34_id28.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0004_id43_id56_id61_id31.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0009_id43_id21_id9_id41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0003_id43_id19_id46_id35.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0007_id43_id24_id27_id45.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0005_id43_id23_id31_id35.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Jessica Alba/0006_id43_id29_id56_id6.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Scarlett Johansson
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0007_id7_id20_id12_id42.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0009_id7_id61_id9_id41.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0002_id7_id48_id6_id46.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0008_id7_id57_id19_id38.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0003_id7_id43_id25_id9.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0001_id7_id56_id41_id3.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0004_id7_id60_id59_id58.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0005_id7_id23_id60_id21.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Scarlett Johansson/0006_id7_id1_id38_id39.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Amir Khan
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0003_id0_id59_id16_id32.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0009_id0_id44_id35_id42.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0006_id0_id40_id58_id21.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0004_id0_id30_id39_id46.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0002_id0_id55_id58_id24.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0000_id0_id11_id48_id43.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0005_id0_id23_id53_id45.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0008_id0_id9_id48_id1.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Amir Khan/0007_id0_id47_id49_id21.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Carrie-Anne Moss
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0006_id57_id10_id54_id8.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0004_id57_id10_id41_id6.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0000_id57_id42_id8_id26.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0001_id57_id25_id54_id24.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0003_id57_id26_id55_id51.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0002_id57_id55_id13_id59.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0007_id57_id4_id25_id13.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0005_id57_id9_id56_id28.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Carrie-Anne Moss/0008_id57_id55_id61_id21.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Angelina Jolie
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0013_id13_id34_id7_id41.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0004_id13_id31_id11_id37.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0001_id13_id17_id33_id3.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0010_id13_id4_id21_id19.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0011_id13_id8_id35_id58.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0000_id13_id24_id28_id58.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0015_id13_id47_id54_id24.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0012_id13_id8_id26_id34.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0007_id13_id23_id60_id52.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0002_id13_id25_id32_id24.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0008_id13_id48_id58_id55.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0009_id13_id19_id60_id31.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0006_id13_id21_id33_id59.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0003_id13_id42_id10_id23.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0014_id13_id25_id51_id31.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/FOM_deepfake_plots/Angelina Jolie/0005_id13_id5_id37_id38.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-

# %% [markdown]
# # CelebDF v2

# %%
dirs=glob("first-order-model/first-order-motion-model/images_names/*")
celeb_dic=get_celebrity_dic("celebrity_id.csv") 
# pprint(dirs)
with open("first-order-model/first-order-motion-model/images_names_result/results.csv","w",buffering=1) as csv_file:
    csv_file.write("Filename,Real, Fake, Real Prediction, Real Prediction Confidence, Fake Prediction,Fake Prediction Confidence,Case\n") 
    for dir in dirs:
    #     print(dir)
        actor_name=os.path.basename(dir)
        print(actor_name)
        files=(glob(os.path.join(dir,"*")))
        for file in files:   
    #         pprint(files)
            file_name=os.path.basename(file)
    #         print(file_name)
            celeb_count,response,image=recognize_celebrities(file)
            print("Celebrities detected: " + str(celeb_count))
            output_s = pprint.pformat(response)
            output_dir=os.path.join("first-order-model/first-order-motion-model/","images_names_result",actor_name)
            output_filename=os.path.join(output_dir,file_name)
            output_log_filename=os.path.join(output_dir,"log_"+os.path.splitext(file_name)[0]+".txt")
    #         print(output_dir)
    #         print(output_filename)
    #         print(output_log_filename)
            if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
            open(output_log_filename, 'w').write(output_s)
            image.save(output_filename)
            real_top=99999
            real_left=99999
            real=99999
            imgWidth,imgHeight  = image.size
            lines=[]
            first=""
            second=""
            third=""
            fourth=""
#             others=[]
            for celebrity in response['CelebrityFaces']:
                box = celebrity['Face']['BoundingBox']
                left = imgWidth * box['Left']
                top = imgHeight * box['Top']
                width = imgWidth * box['Width']
                height = imgHeight * box['Height']
                bot = top + height
                right = left + width
                center_h=top + (height/2)
                center_w=left + (width/2)
#                 if top<(imgHeight/2) and left<(imgWidth/2):#first quadrant
#                     first=celebrity#str(celebrity['Name']+","+str(celebrity['MatchConfidence']))
#                 else:
#                     others.append(celebrity)
                    
                if center_h<(imgHeight/2) and center_w<(imgWidth/2):#first quadrant
                    first=celebrity
                if center_h<(imgHeight/2) and center_w>(imgWidth/2):#second quadrant
                    second=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w<(imgWidth/2):#third quadrant
                    third=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w>(imgWidth/2):#fourth quadrant
                    fourth=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))   


            ids=file_name.split(".")[0].split("_")[1:]
            real_id=ids[0]
            fake_ids=ids[1:]

    #         print(celeb_dic[real_id],celeb_dic[fake_ids[0]])
#             for ii,other in enumerate(fake_ids):
                
#                 csv_file.write(str(file+","+make_output_line(first,other,celeb_dic[real_id],celeb_dic[fake_ids[ii]])+"\n"))
                
            if len(fake_ids)>0:
                csv_file.write(str(file+","+make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]])+"\n"))
            if len(fake_ids) > 1:
                csv_file.write(str(file+","+make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]])+"\n"))
            if len(fake_ids) > 2:
                csv_file.write(str(file+","+make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]])+"\n"))
#             print(make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]]))
#             print(make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]]))
#             print(make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]]))

#             print()
            print("-_-_-_-_-_-_-_-")
    #         break
#         break
# Out:
# Emma Watson
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0000_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0002_id11_id7.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0005_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0001_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0006_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0009_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0010_id11_id7.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0003_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0008_id11_id7.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Emma Watson/0007_id11_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Megan Fox
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0002_id46_id40_id39_id45.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0004_id46_id39_id42_id40.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0008_id46_id41_id47_id40.png
# Celebrities detected: 4
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0003_id46_id47_id45_id39.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0007_id46_id47_id41_id48.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0006_id46_id42_id43_id45.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0001_id46_id39_id47_id42.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0009_id46_id47_id42_id45.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0005_id46_id45_id44_id47.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Megan Fox/0000_id46_id48_id42_id47.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Russell Crowe
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0002_id32_id38_id37_id30.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0004_id32_id35_id30_id37.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0006_id32_id37_id34_id29.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0000_id32_id28_id35_id31.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0008_id32_id28_id21_id26.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0009_id32_id31_id37_id23.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0005_id32_id35_id20_id30.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0001_id32_id33_id29_id30.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0007_id32_id21_id35_id29.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Russell Crowe/0003_id32_id33_id30_id35.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Aamir Khan
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0005_id0_id9_id28_id23.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0001_id0_id21_id6_id20.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0008_id0_id2_id26_id28.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0006_id0_id4_id16_id3.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0009_id0_id20_id28_id17.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0007_id0_id1_id2_id16.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0000_id0_id17_id20_id1.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0002_id0_id28_id16_id6.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0004_id0_id28_id16_id26.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Aamir Khan/0003_id0_id17_id26_id3.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Randall Park
# Detected faces for first-order-model/first-order-motion-model/images_names/Randall Park/0004_id9_id4_id6_id17.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Randall Park/0007_id9_id6_id3_id26.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Randall Park/0003_id9_id28_id0_id16.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Randall Park/0001_id9_id16_id30_id28.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Randall Park/0000_id9_id16_id2_id1.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Randall Park/
png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Carrie-Anne Moss/0003_id57_id51_id56_id52.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Carrie-Anne Moss/0004_id57_id55_id56_id58.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Angelina Jolie
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0008_id13_id7_id10.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0011_id13_id10_id7.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0002_id13_id7.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0007_id13_id10_id7.png
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0003_id13_id7_id10.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0005_id13_id10_id7.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0004_id13_id7_id10.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0009_id13_id7.png
# Celebrities detected: 0
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0001_id13_id10_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0012_id13_id10_id7.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0014_id13_id10.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0000_id13_id7_id10.png
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/images_names/Angelina Jolie/0015_id13_id10_id7.png
# Celebrities detected: 1
# -_-_-_-_-_-_-_-

# %% [markdown]
# # DFP

# %%
dirs=glob("first-order-model/first-order-motion-model/DFP_plots/*")
celeb_dic=get_celebrity_dic("dfp_id.csv") 
# pprint(dirs)
with open("first-order-model/first-order-motion-model/DFP_plots_result/results.csv","w",buffering=1) as csv_file:
    csv_file.write("Filename,Real, Fake, Real Prediction, Real Prediction Confidence, Fake Prediction,Fake Prediction Confidence,Case\n") 
    for dir in dirs:
    #     print(dir)
        actor_name=os.path.basename(dir)
        print(actor_name)
        files=(glob(os.path.join(dir,"*")))
        for file in files:   
    #         pprint(files)
            file_name=os.path.basename(file)
    #         print(file_name)
            celeb_count,response,image=recognize_celebrities(file)
            print("Celebrities detected: " + str(celeb_count))
            output_s = pprint.pformat(response)
            output_dir=os.path.join("first-order-model/first-order-motion-model/","DFP_plots_result",actor_name)
            output_filename=os.path.join(output_dir,file_name)
            output_log_filename=os.path.join(output_dir,"log_"+os.path.splitext(file_name)[0]+".txt")
    #         print(output_dir)
    #         print(output_filename)
    #         print(output_log_filename)
            if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
            open(output_log_filename, 'w').write(output_s)
            image.save(output_filename)
            real_top=99999
            real_left=99999
            real=99999
            imgWidth,imgHeight  = image.size
            lines=[]
            first=""
            second=""
            third=""
            fourth=""
#             others=[]
            for celebrity in response['CelebrityFaces']:
                box = celebrity['Face']['BoundingBox']
                left = imgWidth * box['Left']
                top = imgHeight * box['Top']
                width = imgWidth * box['Width']
                height = imgHeight * box['Height']
                bot = top + height
                right = left + width
                center_h=top + (height/2)
                center_w=left + (width/2)
#                 if top<(imgHeight/2) and left<(imgWidth/2):#first quadrant
#                     first=celebrity#str(celebrity['Name']+","+str(celebrity['MatchConfidence']))
#                 else:
#                     others.append(celebrity)
                    
                if center_h<(imgHeight/2) and center_w<(imgWidth/2):#first quadrant
                    first=celebrity
                if center_h<(imgHeight/2) and center_w>(imgWidth/2):#second quadrant
                    second=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w<(imgWidth/2):#third quadrant
                    third=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                if center_h>(imgHeight/2) and center_w>(imgWidth/2):#fourth quadrant
                    fourth=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))   


            ids=file_name.split(".")[0].split("_")[1:]
            real_id=ids[0]
            fake_ids=ids[1:]

    #         print(celeb_dic[real_id],celeb_dic[fake_ids[0]])
#             for ii,other in enumerate(fake_ids):
                
#                 csv_file.write(str(file+","+make_output_line(first,other,celeb_dic[real_id],celeb_dic[fake_ids[ii]])+"\n"))
                
            if len(fake_ids)>0:
                csv_file.write(str(file+","+make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]])+"\n"))
            if len(fake_ids) > 1:
                csv_file.write(str(file+","+make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]])+"\n"))
            if len(fake_ids) > 2:
                csv_file.write(str(file+","+make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2
    for dir in dirs:
    #     print(dir)
        actor_name=os.path.basename(dir)
        print(actor_name)
        files=(glob(os.path.join(dir,"*")))
        files.sort(key=lambda f: int(re.sub('\D', '', f)))
        for file in files:   
    #         pprint(files)
            file_name=os.path.basename(file)
    #         print(file_name)
            celeb_count,response,image=recognize_celebrities(file)
            print("Celebrities detected: " + str(celeb_count))
            output_s = pprint.pformat(response)
            output_dir=os.path.join("first-order-model/first-order-motion-model/","celebrity_morphing_result",actor_name)
            output_filename=os.path.join(output_dir,file_name)
            output_log_filename=os.path.join(output_dir,"log_"+os.path.splitext(file_name)[0]+".txt")
    #         print(output_dir)
    #         print(output_filename)
    #         print(output_log_filename)
            if not os.path.exists(output_dir):
                    os.makedirs(output_dir)
            open(output_log_filename, 'w').write(output_s)
            image.save(output_filename)
            real_top=99999
            real_left=99999
            real=99999
            imgWidth,imgHeight  = image.size
            lines=[]
            morph=""
            src=""
            tar=""
#             print(file_name)

            for celebrity in response['CelebrityFaces']:
                box = celebrity['Face']['BoundingBox']
                left = imgWidth * box['Left']
                top = imgHeight * box['Top']
                if top<(imgHeight/2):#top half
                    morph=celebrity
                elif top>(imgHeight/2) and left<(imgWidth/2):#bot left
                    src=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))
                elif top>(imgHeight/2) and left>(imgWidth/2):#bot right
                    tar=celebrity#str(","+celebrity['Name']+","+str(celebrity['MatchConfidence']))   
#             print('morph',morph)
#             print('src',src)
#             print('tar',tar)
            
            if src=="":
                src={}
                src['Name']=""                                       
                src['MatchConfidence']=""
            if tar=="":
                tar={}
                tar['Name']=""                                       
                tar['MatchConfidence']=""
            if morph=="":
                morph={}
                morph['Name']=""                                       
                morph['MatchConfidence']=""

            line="{},{},{},{},{},{},{},{},{}\n".format(file,
                                                     str(actor_name),
                                                     str(tar['Name']),                                          
                                                     str(src['Name']),                                          
                                                     str(src['MatchConfidence']),                                          
                                                     str(tar['Name']),                                          
                                                     str(tar['MatchConfidence']),                                          
                                                     str(morph['Name']),                                          
                                                     str(morph['MatchConfidence']))
            csv_file.write(line)
#             print(line)
            print("-_-_-_-_-_-_-_-")
#             break
#         break
    
#             ids=file_name.split(".")[0].split("_")[1:]
#             real_id=ids[0]
#             fake_ids=ids[1:]

    #         print(celeb_dic[real_id],celeb_dic[fake_ids[0]])
    
    
    
#             if len(fake_ids)>0:
#                 csv_file.write(str(file+","+make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]])+"\n"))
#             if len(fake_ids) > 1:
#                 csv_file.write(str(file+","+make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]])+"\n"))
#             if len(fake_ids) > 2:
#                 csv_file.write(str(file+","+make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]])+"\n"))
                
                
                
#             print(make_output_line(first,second,celeb_dic[real_id],celeb_dic[fake_ids[0]]))
#             print(make_output_line(first,third,celeb_dic[real_id],celeb_dic[fake_ids[1]]))
#             print(make_output_line(first,fourth,celeb_dic[real_id],celeb_dic[fake_ids[2]]))

#             print()
#             print("-_-_-_-_-_-_-_-")
    #         break
#         break
# Out:
# Amir Khan
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586501360499.jpg
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586501376100.jpg
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586501395209.jpg
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586501423894.jpg
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586501485682.jpg
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586501511773.jpg
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586503406039.jpg
# Celebrities detected: 3
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/Amir Khan/FaceApp_1586503417001.jpg
# Celebrities detected: 2
# -_-_-_-_-_-_-_-
# Detected faces for first-order-model/first-order-motion-model/celebrity_morphing/